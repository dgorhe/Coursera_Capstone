# %% [markdown]
# ## IBM Data Science Specialization - Final Project
#
# This is the notebook for Darvesh Gorhe's capstone project for the IBM Data Specialization on Coursera

# %%
import pandas as pd
import numpy as np
import requests
import random
from bs4 import BeautifulSoup as bs
import html5lib

from IPython.display import Image
from IPython.core.display import HTML

import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

import geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
geopy.geocoders.options.default_timeout = 7

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Libraries imported.')

print("Hello Capstone Project Course!")
# Out:
# Libraries imported.
# Hello Capstone Project Course!

# %%
CLIENT_ID = 'KGXJMPLRR52DZFGT3KTZPE3ZNVPYSAINZ1FWVEZLEHYOSMZZ' # Foursquare ID
CLIENT_SECRET = 'RJWEQT0O1URM0LDVVN4YJ4E41LK0QOBFQKAYLF32W5LSIJMI' # Foursquare Secret
VERSION = '20200326'
LIMIT = 1000

# %% [markdown]
# ## A. Introduction
#
# ### A.1 Problem Outline
# For this project, I wanted to compare the coffee scene between the neighborhoods in Seattle. The purpose of this is to understand the distribution of coffee shops in the various neighborhoods to see which neighborhoods have high competition among coffee shops and where to open a new coffee shop.
#
# The data presented will be focused on two main audiences: those wanting to open a coffee shop as a small business and coffee chains (e.g. Starbucks, Peet's Tea & Coffee, etc). I picked these two audiences because the same data and analysis would yield different conclusions for each audience. For a large chain, opening a new storefront in an area with many coffee shops could mean that they are competing with their own neighboring storefronts. However, for someone wanting to start a small business, an already dense location would be more optimal since there is already foot traffic and the new business would not be immediately recognized by even local coffee connoisseurs
#
# ### A.2 Data Used
# I will be using the following data from each city for my analysis:
# * Absolute number of coffee shops
# * The number of coffee shops per neighborhood
# * Latitude and Longitude of each coffee shop
# * Addresses of each coffee shop

# %% [markdown]
# # Data - Seattle, Washington

# %%
# URl with all Seattle Neighborhoods
seattle_neighborhoods_url = 'https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Seattle'

# Extracting and Parsing HTML
seattle_wiki = requests.get(seattle_neighborhoods_url)
seattle_soup = bs(seattle_wiki.text, 'html5lib')
seattle_table = seattle_soup.find(name='table', class_='wikitable')

# Retrieving rows of the table with neighborhoods
s_rows = seattle_table.tbody.find_all(name='tr')
s_rows = s_rows[1:]

# %%
# Separating neighborhoods and districts from website

seattle_cols = ['Neighborhood', 'District']

seattle_neigh_df = pd.DataFrame(columns=seattle_cols)

for row in s_rows:
    row_n = row.find_all('td')
    
    if row_n[0].b != None:
        neigh = str(row_n[0].b.string)
    elif row_n[0].a != None:
        neigh = str(row_n[0].a.string)
        
    if row_n[1].string != None:
        district = str(row_n[1].string).replace('\n','')
    elif row_n[1].text != None:
        district = str(row_n[1].text).replace('\n','')
        
    seattle_neigh_df = seattle_neigh_df.append({'Neighborhood': neigh,
                                               'District': district},
                                               ignore_index=True)
    
seattle_neigh_df['District'] = seattle_neigh_df['District'].str.replace(pat='\[(.*?)\]', repl='')

# %%
# Manually correcting some neighborhoods

seattle_neigh_df['Neighborhood'].iloc[100] = 'North Beacon Hill'
seattle_neigh_df['Neighborhood'].iloc[101] = 'Maplewood'
seattle_neigh_df['Neighborhood'].iloc[102] = 'NewHolly'
seattle_neigh_df['Neighborhood'].iloc[103] = 'South Beacon Hill'

seattle_neigh_df
# Out:
#             Neighborhood                                           District  \
# 0          North Seattle                                            Seattle
# 1              Broadview                                      North Seattle
# 2            Bitter Lake                                      North Seattle
# 3            North Beach                                      North Seattle
# 4             Crown Hill                                      North Seattle
# 5              Greenwood                                      North Seattle
# 6              Northgate                                      North Seattle
# 7            Haller Lake                                          Northgate
# 8              Pinehurst                                          Northgate
# 9         Licton Springs                                          Northgate
# 10            Maple Leaf                                          Northgate
# ...

# %%
# Geocoding Neighborhoods

geolocator = Nominatim(user_agent='coursera_project', timeout=5)

df_coordinates = pd.DataFrame(columns=['Neighborhood', 'Latitude', 'Longitude'])

for hood in seattle_neigh_df['Neighborhood']:
    location = geolocator.geocode(hood+", Seattle")
    
    if location != None:
        lat = location.latitude
        lon = location.longitude
    else:
        lat = 'no latitude'
        lon = 'no longitude'
    
    df_coordinates = df_coordinates.append({"Neighborhood": hood,
                                           "Latitude": lat,
                                           "Longitude": lon}, 
                                           ignore_index=True)
    
df_coordinates.head()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %% [markdown]
# ***

# %%
# Retrieving the Coffee Shops

search_query = 'Coffee'
radius = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

shops_seattle = results['response']['venues']
seattle_df = json_normalize(shops_seattle)

# Filtering columns and cleaning dataframe
filtered_cols = ['name', 'categories'] + [col for col in seattle_df.columns if col.startswith('location.')]
seattle_df = seattle_df.loc[:, filtered_cols]

Function to get categories of 
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

seattle_df['categories'] = seattle_df.apply(get_category_type, axis=1)

seattle_df.columns = [column.split('.')[-1] for column in seattle_df.columns]

seattle_df.head()
